# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.4/hadoop-3.3.4.tar.gz 
# !tar -xzvf hadoop-3.3.4.tar.gz 
# !cp -r hadoop-3.3.4/ /usr/local/ 
# !readlink -f /usr/bin/java | sed "s:bin/java::" 
import os 
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64" 
# !/usr/local/hadoop-3.3.4/bin/Hadoop
# Out:
# --2022-09-22 22:22:39--  https://downloads.apache.org/hadoop/common/hadoop-3.3.4/hadoop-3.3.4.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 88.99.95.219, 135.181.214.104, 2a01:4f9:3a:2c57::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|88.99.95.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 695457782 (663M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.4.tar.gz.2’
#
# hadoop-3.3.4.tar.gz 100%[===================>] 663.24M  30.1MB/s    in 28s
#
# 2022-09-22 22:23:07 (23.4 MB/s) - ‘hadoop-3.3.4.tar.gz.2’ saved [695457782/695457782]
#
# hadoop-3.3.4/
# hadoop-3.3.4/licenses-binary/
# hadoop-3.3.4/licenses-binary/LICENSE-dust.txt
# hadoop-3.3.4/licenses-binary/LICENSE-re2j.txt
# hadoop-3.3.4/licenses-binary/LICENSE-slf4j.txt
# hadoop-3.3.4/licenses-binary/LICENSE-jquery.txt
# hadoop-3.3.4/licenses-binary/LICENSE-zstd-jni.txt
# hadoop-3.3.4/licenses-binary/LICENSE-hsql.txt
# ...

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop jar /usr/local/hadoop-3.3.4/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.4.jar
# Out:
# An example program must be given as the first argument.
# Valid program names are:
#   aggregatewordcount: An Aggregate based map/reduce program that counts the words in the input files.
#   aggregatewordhist: An Aggregate based map/reduce program that computes the histogram of the words in the input files.
#   bbp: A map/reduce program that uses Bailey-Borwein-Plouffe to compute exact digits of Pi.
#   dbcount: An example job that count the pageview counts from a database.
#   distbbp: A map/reduce program that uses a BBP-type formula to compute exact bits of Pi.
#   grep: A map/reduce program that counts the matches of a regex in the input.
#   join: A job that effects a join over sorted, equally partitioned datasets
#   multifilewc: A job that counts words from several files.
#   pentomino: A map/reduce tile laying program to find solutions to pentomino problems.
#   pi: A map/reduce program that estimates Pi using a quasi-Monte Carlo method.
# ...

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop jar /usr/local/hadoop-3.3.4/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.4.jar wordcount
# Out:
# Usage: wordcount <in> [<in>...] <out>

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/big-data-Colab/'
# Out:
# 2.DataCopy.ipynb  2.WordCount.ipynb  BigData.ipynb  words2.txt	words.txt

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop jar /usr/local/hadoop-3.3.4/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.4.jar wordcount '/content/drive/My Drive/Colab Notebooks/big-data-Colab/words.txt' '/content/drive/My Drive/Colab Notebooks/big-data-Colab/out'
# Out:
# 2022-09-22 22:23:42,446 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-09-22 22:23:42,657 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-09-22 22:23:42,657 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-09-22 22:23:42,873 INFO input.FileInputFormat: Total input files to process : 1
# 2022-09-22 22:23:42,910 INFO mapreduce.JobSubmitter: number of splits:1
# 2022-09-22 22:23:43,323 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local33366919_0001
# 2022-09-22 22:23:43,323 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2022-09-22 22:23:43,614 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2022-09-22 22:23:43,615 INFO mapreduce.Job: Running job: job_local33366919_0001
# 2022-09-22 22:23:43,630 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# ...

# %%
# !ls '/content/drive/My Drive/Colab Notebooks/big-data-Colab/out'
# Out:
# part-r-00000  _SUCCESS

# %%
# !more '/content/drive/My Drive/Colab Notebooks/big-data-Colab/out/part-r-00000'
# Out:
# "	241
# "'Tis	1
# "A	4
# "AS-IS".	1
# "Air,"	1
# "Alas,	1
# "Amen"	2
# "Amen"?	1
# "Amen,"	1
# "And	1
# "Aroint	1
# "B	1
# "Black	1
# "Break	1
# "Brutus"	1
# "Brutus,	2
# "C	1
# "Caesar"?	1
# "Caesar,	1
# "Caesar."	2
# "Certes,"	1
# "Come	1
# "Cursed	1
